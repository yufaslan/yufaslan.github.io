# %%
import datetime,os
import pandas as pd


#*************************************************
#PANDAS PANDAS PANDAS
#*************************************************
#-----------------------------------------
#url = pd.read_html('http://www.koeri.boun.edu.tr/scripts/lst7.asp')
url = pd.read_html('https://deprem.afad.gov.tr/last-earthquakes.html')

df = url[0] 

#-----------------------------------------
#*************************************************
#ESKİ KOD ÖRNEKLERİ
#df.drop(0, inplace=True)
#df.columns = df.iloc[0] #satırı header yapıyor
#*************************************************

#df.tail()
drive_yol='/'
drive_ad='AFAD DEPREM.xlsx'
drive_tam='{}{}'.format(drive_yol,drive_ad)

df.sort_values('Büyüklük',ascending=False,inplace=True)
df.reset_index(inplace=True)

df2=df[['Tarih(TS)','Yer','Büyüklük','Tip']]

#df2.reset_index(inplace=True)
#df2.drop('index', axis=1, inplace=True)

df2.to_excel(drive_tam, sheet_name='SAYFAM', index=False)

df2.head(10)
# Out:
#              Tarih(TS)                            Yer  Büyüklük Tip
# 0  2023-03-14 19:35:58                        Akdeniz       5.3  MW
# 1  2023-03-14 17:49:47  Çağlayancerit (Kahramanmaraş)       4.9  MW
# 2  2023-03-14 14:57:56              Saimbeyli (Adana)       3.8  ML
# 3  2023-03-14 18:07:30     Onikişubat (Kahramanmaraş)       3.2  ML
# 4  2023-03-14 16:27:35           Doğanşehir (Malatya)       2.8  ML
# 5  2023-03-14 18:37:37            Çelikhan (Adıyaman)       2.8  ML
# 6  2023-03-14 16:48:08         Göksun (Kahramanmaraş)       2.6  ML
# 7  2023-03-14 17:14:09     Onikişubat (Kahramanmaraş)       2.6  ML
# 8  2023-03-14 14:53:41                  Gürün (Sivas)       2.6  ML
# 9  2023-03-14 18:26:21       Elbistan (Kahramanmaraş)       2.5  ML
